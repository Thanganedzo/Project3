# %%
# module that extracts browser history from a user's local computer
import browserhistory as bh

print(bh.get_browserhistory())
# Out:
# * Notification *
# Please Completely Close CHROME Window
# ...
